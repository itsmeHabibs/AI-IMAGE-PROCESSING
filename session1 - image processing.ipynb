# %%
# prompt: write code to load and display an image

from PIL import Image
import matplotlib.pyplot as plt

# Install Pillow library if not already installed
try:
    from PIL import Image
except ImportError:
    # !pip install Pillow
    from PIL import Image

try:
    import matplotlib.pyplot as plt
except ImportError:
    # !pip install matplotlib
    import matplotlib.pyplot as plt


# Example usage
image_path = '/content/image.jpg' # Replace with the actual path to your image file

try:
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')  # Hide axis ticks and labels
    plt.show()
except FileNotFoundError:
    print(f"Error: Image file not found at '{image_path}'")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
img = image.load_img("Furcoat.webp",target_size=(384, 384))
img
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>

# %% [markdown]
# Using a ready made model from Keras applications

# %%
from keras.applications.efficientnet_v2 import EfficientNetV2S, decode_predictions
model = EfficientNetV2S(weights='imagenet')
# Out:
# ...
# 87549136/87549136 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
img_array = image.img_to_array(img)
img_array = img_array.reshape((1, 384, 384, 3))
pred = model.predict(img_array)
decode_predictions(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n03404251', 'fur_coat', 0.9117289),
#   ('n03045698', 'cloak', 0.0023751694),
#   ('n04325704', 'stole', 0.001371511),
#   ('n02817516', 'bearskin', 0.0010477889),
#   ('n04479046', 'trench_coat', 0.000766733)]]

# %% [markdown]
# **SOME EXPERIMENT BY ME:**

# %%
img = image.load_img("dog.png",target_size=(384, 384))
img
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>

# %%
from keras.applications.efficientnet_v2 import EfficientNetV2S, decode_predictions
model = EfficientNetV2S(weights='imagenet')

# %%
img_array = image.img_to_array(img)
img_array = img_array.reshape((1, 384, 384, 3))
pred = model.predict(img_array)
decode_predictions(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# [[('n02099601', 'golden_retriever', 0.88163054),
#   ('n02099712', 'Labrador_retriever', 0.00454638),
#   ('n04409515', 'tennis_ball', 0.0028746682),
#   ('n02102480', 'Sussex_spaniel', 0.0019879097),
#   ('n02111129', 'Leonberg', 0.0014830993)]]

# %%
png_1=image.load_img("png_1.png",target_size=(384,384))
png_1_array = image.img_to_array(png_1)
png_1_array = png_1_array.reshape((1, 384, 384,3))
pred = model.predict(png_1_array)
decode_predictions(pred)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-403e515335ed> in <cell line: 0>()
# ----> 1 png_1=image.load_img("png_1.png",target_size=(384,384))
#       2 png_1_array = image.img_to_array(png_1)
#       3 png_1_array = png_1_array.reshape((1, 384, 384,3))
#       4 pred = model.predict(png_1_array)
#       5 decode_predictions(pred)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/image_utils.py in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233         if isinstance(path, pathlib.Path):
#     234             path = str(path.resolve())
# --> 235         with open(path, "rb") as f:
#     236             img = pil_image.open(io.BytesIO(f.read()))
#     237     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'png_1.png'

# %%
png_2=image.load_img("png_2.png",target_size=(384,384))
png_2_array = image.img_to_array(png_2)
png_2_array = png_2_array.reshape((1, 384, 384,3))
pred = model.predict(png_2_array)
decode_predictions(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# [[('n03347037', 'fire_screen', 0.8657612),
#   ('n04330267', 'stove', 0.03812653),
#   ('n04589890', 'window_screen', 0.0031144076),
#   ('n09472597', 'volcano', 0.0009851654),
#   ('n02939185', 'caldron', 0.00082218874)]]

# %%
jpeg_1=image.load_img("jpeq_1.png",target_size=(384,384))
jpeg_1_array = image.img_to_array(jpeg_1)
jpeg_1_array = jpeg_1_array.reshape((1, 384, 384,3))
pred = model.predict(jpeg_1_array)
decode_predictions(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# [[('n03598930', 'jigsaw_puzzle', 0.90748787),
#   ('n07860988', 'dough', 0.0005831968),
#   ('n03908714', 'pencil_sharpener', 0.00042464054),
#   ('n03452741', 'grand_piano', 0.00042180534),
#   ('n03992509', "potter's_wheel", 0.00040986112)]]

# %%
bmp_1=image.load_img("bmp_1.png",target_size=(384,384))
bmp_1_array = image.img_to_array(bmp_1)
bmp_1_array = bmp_1_array.reshape((1, 384, 384,3))
pred = model.predict(bmp_1_array)
decode_predictions(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 771ms/step
# [[('n09468604', 'valley', 0.809595),
#   ('n09193705', 'alp', 0.11080176),
#   ('n09246464', 'cliff', 0.006565657),
#   ('n09332890', 'lakeside', 0.0017951742),
#   ('n03160309', 'dam', 0.0017737523)]]

# %%
gif_1=image.load_img("gif_1.png",target_size=(384,384))
gif_1_array = image.img_to_array(gif_1)
gif_1_array = gif_1_array.reshape((1, 384, 384,3))
pred = model.predict(gif_1_array)
decode_predictions(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# [[('n02123597', 'Siamese_cat', 0.91245157),
#   ('n02124075', 'Egyptian_cat', 0.0022267539),
#   ('n02123394', 'Persian_cat', 0.0008457847),
#   ('n02123045', 'tabby', 0.0005918412),
#   ('n04589890', 'window_screen', 0.0005857856)]]
